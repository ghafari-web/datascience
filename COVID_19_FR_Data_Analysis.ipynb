# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-90afbbf3-8c60-4dfc-8ff3-1fdc15d7d810" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90afbbf3-8c60-4dfc-8ff3-1fdc15d7d810">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving synthese-fr.csv to synthese-fr.csv
# ...

# %%
data = pd.read_csv("synthese-fr.csv")

# %%
data.shape
# Out:
# (596, 11)

# %%
data.head()
# Out:
#          date  ...  nouveaux_patients_reanimation
# 0  2020-03-02  ...                            NaN
# 1  2020-03-03  ...                            NaN
# 2  2020-03-04  ...                            NaN
# 3  2020-03-05  ...                            NaN
# 4  2020-03-06  ...                            NaN
#
# [5 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596 entries, 0 to 595
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   date                            596 non-null    object
#  1   total_cas_confirmes             596 non-null    int64
#  2   total_deces_hopital             596 non-null    int64
#  3   total_deces_ehpad               564 non-null    float64
#  4   total_cas_confirmes_ehpad       313 non-null    float64
#  5   total_cas_possibles_ehpad       15 non-null     float64
#  6   patients_reanimation            590 non-null    float64
#  7   patients_hospitalises           582 non-null    float64
#  8   total_patients_gueris           582 non-null    float64
#  9   nouveaux_patients_hospitalises  579 non-null    float64
#  10  nouveaux_patients_reanimation   579 non-null    float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 51.3+ KB

# %%
data.columns
# Out:
# Index(['date', 'total_cas_confirmes', 'total_deces_hopital',
#        'total_deces_ehpad', 'total_cas_confirmes_ehpad',
#        'total_cas_possibles_ehpad', 'patients_reanimation',
#        'patients_hospitalises', 'total_patients_gueris',
#        'nouveaux_patients_hospitalises', 'nouveaux_patients_reanimation'],
#       dtype='object')

# %%
data.tail()
# Out:
#            date  ...  nouveaux_patients_reanimation
# 591  2021-10-14  ...                           44.0
# 592  2021-10-15  ...                           43.0
# 593  2021-10-16  ...                           25.0
# 594  2021-10-17  ...                           18.0
# 595  2021-10-18  ...                           67.0
#
# [5 rows x 11 columns]

# %%
data.describe()
# Out:
#        total_cas_confirmes  ...  nouveaux_patients_reanimation
# count         5.960000e+02  ...                     579.000000
# mean          2.913384e+06  ...                     172.872193
# std           2.569567e+06  ...                     156.378348
# min           1.910000e+02  ...                       1.000000
# 25%           1.848480e+05  ...                      39.500000
# 50%           2.537640e+06  ...                     135.000000
# 75%           5.708950e+06  ...                     262.500000
# max           7.090109e+06  ...                     771.000000
#
# [8 rows x 10 columns]

# %%
data.isnull().sum()
# Out:
# date                                0
# total_cas_confirmes                 0
# total_deces_hopital                 0
# total_deces_ehpad                  32
# total_cas_confirmes_ehpad         283
# total_cas_possibles_ehpad         581
# patients_reanimation                6
# patients_hospitalises              14
# total_patients_gueris              14
# nouveaux_patients_hospitalises     17
# nouveaux_patients_reanimation      17
# dtype: int64

# %%
data.columns
# Out:
# Index(['date', 'total_cas_confirmes', 'total_deces_hopital',
#        'total_deces_ehpad', 'total_cas_confirmes_ehpad',
#        'total_cas_possibles_ehpad', 'patients_reanimation',
#        'patients_hospitalises', 'total_patients_gueris',
#        'nouveaux_patients_hospitalises', 'nouveaux_patients_reanimation'],
#       dtype='object')

# %%
#mettre en relation les variables avec scatterplots

# %%
sns.relplot(x="total_cas_confirmes",y="nouveaux_patients_hospitalises",hue="total_patients_gueris",data=data)

# %%
sns.pairplot(data)

# %%
sns.catplot(x="total_patients_gueris",y="total_cas_confirmes",data=data)
